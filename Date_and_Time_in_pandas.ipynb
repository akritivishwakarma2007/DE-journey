# %% [markdown]
# <a href="https://colab.research.google.com/github/akritivishwakarma2007/DE-journey/blob/main/Date_and_Time_in_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Timestamp Object
#
# Time stamps reference particular moments in time (e.g., Oct 24th, 2022 at 7:00pm)

# %% [markdown]
# ### Creating Timestamp objects

# %%
# creating a timestamp
type(pd.Timestamp('2023/1/5'))
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# variations
pd.Timestamp('2023-1-5')
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
pd.Timestamp('2023, 1, 5')
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
# only year
pd.Timestamp('2023')
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
# using text
pd.Timestamp('5th January 2023')
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
# providing time also
pd.Timestamp('5th January 2023 9:21AM')
# Out:
# Timestamp('2023-01-05 09:21:00')

# %%
# AM and PM
