# %% [markdown]
# <a href="https://colab.research.google.com/github/akritivishwakarma2007/DE-journey/blob/main/Oop_concept_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### How objects access attributes

# %%
class Person:

  def __init__(self,name_input,country_input):
    self.name = name_input
    self.country = country_input

  def greet(self):
    if self.country == 'india':
      print('Namaste',self.name)
    else:
      print('Hello',self.name)

# %%
# how to access attributes
p = Person('nitish','india')

# %%
p.name
# Out:
# 'nitish'

# %%
# how to access methods
p.greet()
# Out:
# Namaste nitish

# %%
# what if i try to access non-existent attributes
p.gender
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1749/4288628511.py in <cell line: 0>()
#       1 # what if i try to access non-existent attributes
# ----> 2 p.gender
#
# AttributeError: 'Person' object has no attribute 'gender'

# %% [markdown]
# ### Attribute creation from outside of the class

# %%
p.gender = 'male'

# %%
p.gender
# Out:
# 'male'

# %% [markdown]
# ### Reference Variables
#
# - Reference variables hold the objects
# - We can create objects without reference variable as well
# - An object can have multiple reference variables
# - Assigning a new reference variable to an existing object does not create a new object

# %%
# object without a reference
class Person:

  def __init__(self):
    self.name = 'nitish'
    self.gender = 'male'

p = Person()
q = p

# %%
# Multiple ref
print(id(p))
print(id(q))
# Out:
# 134573318637760
# 134573318637760

# %%
print(p.name)
print(q.name)
q.name = 'ankit'
print(q.name)
print(p.name)
# Out:
# nitish
# nitish
# ankit
# ankit

# %% [markdown]
# Pass by reference

# %%
class Person:

  def __init__(self,name,gender):
    self.name= name
    self.gender = gender

def greet(Person):
  print("hii my name is", Person.name, "and i am a", Person.gender)

p = Person('Akriti', 'female')
greet(p)
# Out:
# hii my name is Akriti and i am a female
